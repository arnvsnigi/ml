# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree

df=pd.read_csv('Iris.csv')
df

# iris=load_iris()
# X=iris.data
# y=iris.target
# feature_names=iris.feature_names
# class_names=iris.target_names
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns=['Id','Species'])
y=df['Species']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=dtc.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.98

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

feature_namess = X.columns
class_namess = ['setosa', 'versicolor', 'virginica']
plt.figure(figsize=(20,10))  # Set the size of the plot
plot_tree(dtc, filled=True, feature_names=feature_namess, class_names=class_namess, rounded=True)
plt.show()

# %%
y_pred = dtc.predict([['5.7', '2.2', '2.3', '3.9']])
y_pred
# Out:
# /Users/arvindkumarsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)
